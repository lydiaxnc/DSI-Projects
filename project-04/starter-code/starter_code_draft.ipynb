# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
## YOUR CODE HERE

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above

# %%
## YOUR CODE HERE

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# #### Complete the following code to collect results from multiple cities and starting points.
# - Enter your city below to add it to the search
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
YOUR_CITY = ''

# %%
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
max_results_per_city = 100

results = []

for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', YOUR_CITY]):
    for start in range(0, max_results_per_city, 10):
        # Grab the results from the request (as above)
        # Append to the full set of results
        pass

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
## YOUR CODE HERE

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now
# 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
## YOUR CODE HERE

# %% [markdown]
# ### Save your results as a CSV

# %%
## YOUR CODE HERE

# %% [markdown]
# # CLEAN DATA

# %%
import pandas as pd

# %%
df = pd.read_csv('../../../project_data/indeed-scraped-job-postings.csv')

# %%
df
# Out:
#                city                                company  \
# 0     San+Francisco                            MarkMonitor
# 1     San+Francisco                  Workbridge Associates
# 2     San+Francisco                               Mines.io
# 3     San+Francisco                  Workbridge Associates
# 4     San+Francisco                Smith Hanley Associates
# 5     San+Francisco                         HSF Consulting
# 6     San+Francisco                       All-In Analytics
# 7     San+Francisco                                Brilent
# 8     San+Francisco                         HSF Consulting
# 9     San+Francisco                       All-In Analytics
# 10    San+Francisco                     Jobspring Partners
# 11    San+Francisco      University of California Berkeley
# 12    San+Francisco                  Workbridge Associates
# 13    San+Francisco                         HSF Consulting
# 14    San+Francisco      University of California Berkeley
# 15    San+Francisco                  Workbridge Associates
# 16    San+Francisco                  Workbridge Associates
# 17    San+Francisco                  Workbridge Associates
# 18    San+Francisco                  Workbridge Associates
# 19    San+Francisco              Corporate Labs Technology
# 20    San+Francisco                                Brilent
# 21    San+Francisco                  Workbridge Associates
# 22    San+Francisco                                 3coast
# 23    San+Francisco      University of California Berkeley
# 24    San+Francisco                     NextGen Jane, Inc.
# 25    San+Francisco                     Jobspring Partners
# 26    San+Francisco                  Workbridge Associates
# 27    San+Francisco                  Workbridge Associates
# 28    San+Francisco                  Workbridge Associates
# 29    San+Francisco  Talent Compliance Consulting Services
# ...             ...                                    ...
# 4761        Chicago                  Workbridge Associates
# 4762        Chicago        Clinical Management Consultants
# 4763        Chicago                  Workbridge Associates
# 4764        Chicago        Clinical Management Consultants
# 4765        Chicago                  Workbridge Associates
# 4766        Chicago                  Workbridge Associates
# 4767        Chicago        Clinical Management Consultants
# 4768        Chicago                  Workbridge Associates
# 4769        Chicago                  Workbridge Associates
# 4770        Chicago        Clinical Management Consultants
# 4771        Chicago                  Workbridge Associates
# 4772        Chicago                  Workbridge Associates
# 4773        Chicago                  Workbridge Associates
# 4774        Chicago        Clinical Management Consultants
# 4775        Chicago                  Workbridge Associates
# 4776        Chicago                  Workbridge Associates
# 4777        Chicago        Clinical Management Consultants
# 4778        Chicago                  Workbridge Associates
# 4779        Chicago        Clinical Management Consultants
# 4780        Chicago                  Workbridge Associates
# 4781        Chicago        Clinical Management Consultants
# 4782        Chicago                  Workbridge Associates
# 4783        Chicago                  Workbridge Associates
# 4784        Chicago        Clinical Management Consultants
# 4785        Chicago                  Workbridge Associates
# 4786        Chicago                  Workbridge Associates
# 4787        Chicago        Clinical Management Consultants
# 4788        Chicago                  Workbridge Associates
# 4789        Chicago        Clinical Management Consultants
# 4790        Chicago                  Workbridge Associates
#
#                           salary  \
# 0                $180,000 a year
# 1     $130,000 - $180,000 a year
# 2      $80,000 - $120,000 a year
# 3     $150,000 - $180,000 a year
# 4                $140,000 a year
# 5                $300,000 a year
# 6     $100,000 - $150,000 a year
# 7                $130,000 a year
# 8                $160,000 a year
# 9     $100,000 - $150,000 a year
# 10    $150,000 - $175,000 a year
# 11       $3,811 - $3,889 a month
# 12    $100,000 - $200,000 a year
# 13               $300,000 a year
# 14      $43,692 - $51,120 a year
# 15    $130,000 - $180,000 a year
# 16    $100,000 - $200,000 a year
# 17    $130,000 - $150,000 a year
# 18    $100,000 - $140,000 a year
# 19    $110,000 - $180,000 a year
# 20               $150,000 a year
# 21    $140,000 - $200,000 a year
# 22     $80,000 - $200,000 a year
# 23      $67,500 - $81,600 a year
# 24                $65,000 a year
# 25    $180,000 - $275,000 a year
# 26    $130,000 - $150,000 a year
# 27    $100,000 - $140,000 a year
# 28    $140,000 - $200,000 a year
# 29               $100,000 a year
# ...                          ...
# 4761  $110,000 - $150,000 a year
# 4762    $71,384 - $93,274 a year
# 4763             $170,000 a year
# 4764    $71,384 - $93,274 a year
# 4765             $170,000 a year
# 4766  $110,000 - $150,000 a year
# 4767    $71,384 - $93,274 a year
# 4768             $170,000 a year
# 4769  $110,000 - $150,000 a year
# 4770    $71,384 - $93,274 a year
# 4771             $170,000 a year
# 4772  $110,000 - $150,000 a year
# 4773  $110,000 - $150,000 a year
# 4774    $71,384 - $93,274 a year
# 4775             $170,000 a year
# 4776  $110,000 - $150,000 a year
# 4777    $71,384 - $93,274 a year
# 4778             $170,000 a year
# 4779    $71,384 - $93,274 a year
# 4780             $170,000 a year
# 4781    $71,384 - $93,274 a year
# 4782             $170,000 a year
# 4783  $110,000 - $150,000 a year
# 4784    $71,384 - $93,274 a year
# 4785             $170,000 a year
# 4786  $110,000 - $150,000 a year
# 4787    $71,384 - $93,274 a year
# 4788             $170,000 a year
# 4789    $71,384 - $93,274 a year
# 4790             $170,000 a year
#
#                                                 summary  \
# 0     Data skills (SQL, Hive, Pig). Applying machine...
# 1     3+ years of industry experience in a data scie...
# 2     We are looking for a data scientist/developer ...
# 3     In this position you will share programming an...
# 4     This person will recruit, build and lead a tea...
# 5     Teams included Data Services(including data en...
# 6     Fraud Data Scientist. Seeking someone with ski...
# 7     Perform large-scale data analysis, find intere...
# 8     More data- they simply have more data than the...
# 9     Fraud Data Scientist. Seeking someone with ski...
# 10    Given the high volume of data collected by the...
# 11    Must be able to work in a greenhouse, manage d...
# 12    You will collaborate with Product, Data Engine...
# 13    Teams included Data Services(including data en...
# 14    Demonstrated experience with programming for b...
# 15    This leading company has a job opening for Pri...
# 16    You will collaborate with Product, Data Engine...
# 17    2+ years of experience in Data Scientist, Quan...
# 18    Solid experience in data science. Established ...
# 19    Machine Learning Developer Brisbane, CA Sign o...
# 20    The Brilent team brings together deep experien...
# 21    The Senior Data Scientist position requires a ...
# 22    VP - Predictive Modeling / Data Scientist. Han...
# 23    Ensures accuracy and completeness of data in m...
# 24    Scientific Researcher – Next Gen Sequencing Sc...
# 25    This is an opportunity to lead a team of talen...
# 26    2+ years of experience in Data Scientist, Quan...
# 27    Solid experience in data science. Established ...
# 28    The Senior Data Scientist position requires a ...
# 29    Strong data analysis skills including setting ...
# ...                                                 ...
# 4761  This agile team will create and develop new so...
# 4762  Manager Health Information Management Data Ana...
# 4763  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4764  Manager Health Information Management Data Ana...
# 4765  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4766  This agile team will create and develop new so...
# 4767  Manager Health Information Management Data Ana...
# 4768  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4769  This agile team will create and develop new so...
# 4770  Manager Health Information Management Data Ana...
# 4771  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4772  This agile team will create and develop new so...
# 4773  This agile team will create and develop new so...
# 4774  Manager Health Information Management Data Ana...
# 4775  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4776  This agile team will create and develop new so...
# 4777  Manager Health Information Management Data Ana...
# 4778  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4779  Manager Health Information Management Data Ana...
# 4780  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4781  Manager Health Information Management Data Ana...
# 4782  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4783  This agile team will create and develop new so...
# 4784  Manager Health Information Management Data Ana...
# 4785  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4786  This agile team will create and develop new so...
# 4787  Manager Health Information Management Data Ana...
# 4788  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4789  Manager Health Information Management Data Ana...
# 4790  Big Data with Hadoop, Hive, Impala. Mid, Senio...
#
#                                                   title  parsed_salary
# 0                                        Data Scientist       180000.0
# 1                                 Senior Data Scientist       155000.0
# 2                             Full-Stack Data Scientist       100000.0
# 3                                        Data Scientist       165000.0
# 4                                        Data Scientist       140000.0
# 5                                   VP of Data Services       300000.0
# 6                                  Fraud Data Scientist       125000.0
# 7                                 Senior Data Scientist       130000.0
# 8                                 Senior Data Scientist       160000.0
# 9                                  Fraud Data Scientist       125000.0
# 10                  Python Developer (Machine Learning)       162500.0
# 11                        Staff Research Associate, PMB         3850.0
# 12    Chief Algorithm Developer (Signal Processing) ...       150000.0
# 13                                  VP of Data Services       300000.0
# 14    Post-Doctoral Scholar-Employee: Analysis of om...        47406.0
# 15                             Principal Data Scientist       155000.0
# 16    Chief Algorithm Developer (Signal Processing) ...       150000.0
# 17                        Data Scientist (Econometrics)       140000.0
# 18                Data Scientist (Statistics/Economics)       120000.0
# 19                    Data Scientist (Machine Learning)       145000.0
# 20                        Senior NLP Scientist/Engineer       150000.0
# 21    Senior Data Scientist (Autonomous Vehicle Rese...       170000.0
# 22            VP - Predictive Modeling / Data Scientist       140000.0
# 23                          Database Administrator, GSE        74550.0
# 24                                Scientific Researcher        65000.0
# 25    Vice President Engineering (Big Data/ Machine ...       227500.0
# 26                        Data Scientist (Econometrics)       140000.0
# 27                Data Scientist (Statistics/Economics)       120000.0
# 28    Senior Data Scientist (Autonomous Vehicle Rese...       170000.0
# 29                            Quality Control Scientist       100000.0
# ...                                                 ...            ...
# 4761                     Senior Java Computer Scientist       130000.0
# 4762  Manager Health Information Management Data Ana...        82329.0
# 4763                         Director of Data Analytics       170000.0
# 4764  Manager Health Information Management Data Ana...        82329.0
# 4765                         Director of Data Analytics       170000.0
# 4766                     Senior Java Computer Scientist       130000.0
# 4767  Manager Health Information Management Data Ana...        82329.0
# 4768                         Director of Data Analytics       170000.0
# 4769                     Senior Java Computer Scientist       130000.0
# 4770  Manager Health Information Management Data Ana...        82329.0
# 4771                         Director of Data Analytics       170000.0
# 4772                     Senior Java Computer Scientist       130000.0
# 4773                     Senior Java Computer Scientist       130000.0
# 4774  Manager Health Information Management Data Ana...        82329.0
# 4775                         Director of Data Analytics       170000.0
# 4776                     Senior Java Computer Scientist       130000.0
# 4777  Manager Health Information Management Data Ana...        82329.0
# 4778                         Director of Data Analytics       170000.0
# 4779  Manager Health Information Management Data Ana...        82329.0
# 4780                         Director of Data Analytics       170000.0
# 4781  Manager Health Information Management Data Ana...        82329.0
# 4782                         Director of Data Analytics       170000.0
# 4783                     Senior Java Computer Scientist       130000.0
# 4784  Manager Health Information Management Data Ana...        82329.0
# 4785                         Director of Data Analytics       170000.0
# 4786                     Senior Java Computer Scientist       130000.0
# 4787  Manager Health Information Management Data Ana...        82329.0
# 4788                         Director of Data Analytics       170000.0
# 4789  Manager Health Information Management Data Ana...        82329.0
# 4790                         Director of Data Analytics       170000.0
#
# [4791 rows x 6 columns]

# %%
df.salary.value_counts()
# Out:
# $5,400 - $6,500 a month       788
# $3,210 a month                783
# $6,250 - $10,833 a month      699
# $170,000 a year               390
# $70,000 - $100,000 a year     390
# $71,384 - $93,274 a year      389
# $110,000 - $150,000 a year    365
# $120,000 - $155,000 a year    356
# $140,000 - $160,000 a year    336
# $4,193 - $6,003 a month        35
# $68,239 - $85,644 a year       14
# $65,000 a year                  7
# $140,000 a year                 7
# $200,000 a year                 7
# $100,000 - $200,000 a year      6
# $120,000 a year                 6
# $57,969 - $70,142 a year        5
# $100,000 - $140,000 a year      5
# $150,000 a year                 5
# $185,000 a year                 5
# $85,000 a year                  5
# $150,000 - $230,000 a year      4
# $150,000 - $200,000 a year      4
# $2,948 - $3,929 a month         4
# $100,000 a year                 4
# $110,000 - $130,000 a year      4
# $100,000 - $150,000 a year      3
# $7,083 - $9,166 a month         3
# $80,000 - $200,000 a year       3
# $180,000 a year                 3
#                              ...
# $57,969 - $62,000 a year        1
# $3,017 - $4,032 a month         1
# $100,000 - $120,000 a year      1
# $8,333 a month                  1
# $115,000 - $150,000 a year      1
# $50,000 - $65,000 a year        1
# $42,802 - $55,643 a year        1
# $150,000 - $180,000 a year      1
# $68,239 - $85,556 a year        1
# $95,000 a year                  1
# $71,000 a year                  1
# $3,763 - $5,665 a month         1
# $66,575 - $76,561 a year        1
# $4,599 - $5,333 a month         1
# $120,000 - $140,000 a year      1
# $165,000 - $195,000 a year      1
# $75,000 a year                  1
# $37,000 - $45,000 a year        1
# $60,000 a year                  1
# $100,000 - $170,000 a year      1
# $125,000 a year                 1
# $75,000 - $95,000 a year        1
# $43,692 - $51,120 a year        1
# $175,000 - $275,000 a year      1
# $150,000 - $250,000 a year      1
# $4,950 - $7,826 a month         1
# $67,500 - $81,600 a year        1
# $200,000 - $300,000 a year      1
# $4,459 a month                  1
# $60,000 - $120,000 a year       1
# Name: salary, dtype: int64

# %%
df.loc[df.salary.str.contains('year'), 'yearly_salary'] = df['salary']
df.loc[df.salary.str.contains('month'), 'monthly_salary'] = df['salary']

df.yearly_salary.value_counts()
# Out:
# $70,000 - $100,000 a year     390
# $170,000 a year               390
# $71,384 - $93,274 a year      389
# $110,000 - $150,000 a year    365
# $120,000 - $155,000 a year    356
# $140,000 - $160,000 a year    336
# $68,239 - $85,644 a year       14
# $140,000 a year                 7
# $200,000 a year                 7
# $65,000 a year                  7
# $100,000 - $200,000 a year      6
# $120,000 a year                 6
# $57,969 - $70,142 a year        5
# $100,000 - $140,000 a year      5
# $185,000 a year                 5
# $85,000 a year                  5
# $150,000 a year                 5
# $150,000 - $200,000 a year      4
# $150,000 - $230,000 a year      4
# $110,000 - $130,000 a year      4
# $100,000 a year                 4
# $160,000 a year                 3
# $130,000 a year                 3
# $180,000 a year                 3
# $100,000 - $150,000 a year      3
# $80,000 - $200,000 a year       3
# $130,000 - $175,000 a year      3
# $140,000 - $200,000 a year      3
# $80,000 - $120,000 a year       3
# $76,340 - $100,322 a year       3
#                              ...
# $68,239 - $85,556 a year        1
# $165,000 - $195,000 a year      1
# $70,000 - $110,000 a year       1
# $125,000 - $150,000 a year      1
# $43,692 - $51,120 a year        1
# $125,000 a year                 1
# $37,000 - $45,000 a year        1
# $115,000 - $150,000 a year      1
# $95,000 a year                  1
# $150,000 - $180,000 a year      1
# $40,000 a year                  1
# $60,000 a year                  1
# $75,000 a year                  1
# $85,211 - $110,522 a year       1
# $57,969 a year                  1
# $60,000 - $68,000 a year        1
# $120,000 - $140,000 a year      1
# $120,000 - $160,000 a year      1
# $60,000 - $120,000 a year       1
# $150,000 - $250,000 a year      1
# $75,000 - $95,000 a year        1
# $42,802 - $55,643 a year        1
# $49,012 a year                  1
# $80,000 a year                  1
# $40,000 - $65,000 a year        1
# $67,500 - $81,600 a year        1
# $71,000 a year                  1
# $50,000 - $65,000 a year        1
# $66,575 - $76,561 a year        1
# $80,000 - $110,000 a year       1
# Name: yearly_salary, dtype: int64

# %%
sum(df.salary.value_counts())
# Out:
# 4791

# %%
type(df.salary[0])
# Out:
# str

# %%
df['yearly_salary']
# Out:
# 0                  $180,000 a year
# 1       $130,000 - $180,000 a year
# 2        $80,000 - $120,000 a year
# 3       $150,000 - $180,000 a year
# 4                  $140,000 a year
# 5                  $300,000 a year
# 6       $100,000 - $150,000 a year
# 7                  $130,000 a year
# 8                  $160,000 a year
# 9       $100,000 - $150,000 a year
# 10      $150,000 - $175,000 a year
# 11                             NaN
# 12      $100,000 - $200,000 a year
# 13                 $300,000 a year
# 14        $43,692 - $51,120 a year
# 15      $130,000 - $180,000 a year
# 16      $100,000 - $200,000 a year
# 17      $130,000 - $150,000 a year
# 18      $100,000 - $140,000 a year
# 19      $110,000 - $180,000 a year
# 20                 $150,000 a year
# 21      $140,000 - $200,000 a year
# 22       $80,000 - $200,000 a year
# 23        $67,500 - $81,600 a year
# 24                  $65,000 a year
# 25      $180,000 - $275,000 a year
# 26      $130,000 - $150,000 a year
# 27      $100,000 - $140,000 a year
# 28      $140,000 - $200,000 a year
# 29                 $100,000 a year
#                    ...
# 4761    $110,000 - $150,000 a year
# 4762      $71,384 - $93,274 a year
# 4763               $170,000 a year
# 4764      $71,384 - $93,274 a year
# 4765               $170,000 a year
# 4766    $110,000 - $150,000 a year
# 4767      $71,384 - $93,274 a year
# 4768               $170,000 a year
# 4769    $110,000 - $150,000 a year
# 4770      $71,384 - $93,274 a year
# 4771               $170,000 a year
# 4772    $110,000 - $150,000 a year
# 4773    $110,000 - $150,000 a year
# 4774      $71,384 - $93,274 a year
# 4775               $170,000 a year
# 4776    $110,000 - $150,000 a year
# 4777      $71,384 - $93,274 a year
# 4778               $170,000 a year
# 4779      $71,384 - $93,274 a year
# 4780               $170,000 a year
# 4781      $71,384 - $93,274 a year
# 4782               $170,000 a year
# 4783    $110,000 - $150,000 a year
# 4784      $71,384 - $93,274 a year
# 4785               $170,000 a year
# 4786    $110,000 - $150,000 a year
# 4787      $71,384 - $93,274 a year
# 4788               $170,000 a year
# 4789      $71,384 - $93,274 a year
# 4790               $170,000 a year
# Name: yearly_salary, dtype: object

# %%
df['yearly_salary'].str.extract('(\d+)').astype(float)

# [int(df['yearly_salary']) for df.yearly_salary in str.split() if s.isdigit()]
# Out:
# /Users/Lydia/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   if __name__ == '__main__':
# 0       180.0
# 1       130.0
# 2        80.0
# 3       150.0
# 4       140.0
# 5       300.0
# 6       100.0
# 7       130.0
# 8       160.0
# 9       100.0
# 10      150.0
# 11        NaN
# 12      100.0
# 13      300.0
# 14       43.0
# 15      130.0
# 16      100.0
# 17      130.0
# 18      100.0
# 19      110.0
# 20      150.0
# 21      140.0
# 22       80.0
# 23       67.0
# 24       65.0
# 25      180.0
# 26      130.0
# 27      100.0
# 28      140.0
# 29      100.0
#         ...
# 4761    110.0
# 4762     71.0
# 4763    170.0
# 4764     71.0
# 4765    170.0
# 4766    110.0
# 4767     71.0
# 4768    170.0
# 4769    110.0
# 4770     71.0
# 4771    170.0
# 4772    110.0
# 4773    110.0
# 4774     71.0
# 4775    170.0
# 4776    110.0
# 4777     71.0
# 4778    170.0
# 4779     71.0
# 4780    170.0
# 4781     71.0
# 4782    170.0
# 4783    110.0
# 4784     71.0
# 4785    170.0
# 4786    110.0
# 4787     71.0
# 4788    170.0
# 4789     71.0
# 4790    170.0
# Name: yearly_salary, dtype: float64

# %%
range_l = []
range_h = []
for x in df['yearly_salary']: 
    try:
        range_l.append(x.split()[0])
        range_h.append(x.split()[2])
    except:
        range_l.append(np.nan)
        range_h.append(np.nan)
df.range_low = range_l
df.range_high = range_h

df.range_low.value_counts()
# Out:
# $70,000     393
# $170,000    390
# $71,384     389
# $110,000    371
# $120,000    366
# $140,000    350
# $100,000     20
# $150,000     17
# $68,239      17
# $130,000     12
# $80,000      10
# $200,000      8
# $57,969       7
# $65,000       7
# $180,000      7
# $85,000       5
# $185,000      5
# $60,000       5
# $76,340       4
# $40,000       3
# $160,000      3
# $115,000      3
# $50,000       3
# $69,749       2
# $71,510       2
# $135,000      2
# $165,000      2
# $75,000       2
# $61,000       2
# $42,000       2
# $75,925       2
# $125,000      2
# $77,000       2
# $117,500      2
# $35,000       2
# $300,000      2
# $105,000      2
# $41,993       1
# $37,000       1
# $43,692       1
# $42,802       1
# $49,012       1
# $66,575       1
# $41,057       1
# $95,000       1
# $85,211       1
# $67,500       1
# $50,400       1
# $71,000       1
# $53,875       1
# $175,000      1
# Name: range_low, dtype: int64

# %%
df
# Out:
#                city                                company  \
# 0     San+Francisco                            MarkMonitor
# 1     San+Francisco                  Workbridge Associates
# 2     San+Francisco                               Mines.io
# 3     San+Francisco                  Workbridge Associates
# 4     San+Francisco                Smith Hanley Associates
# 5     San+Francisco                         HSF Consulting
# 6     San+Francisco                       All-In Analytics
# 7     San+Francisco                                Brilent
# 8     San+Francisco                         HSF Consulting
# 9     San+Francisco                       All-In Analytics
# 10    San+Francisco                     Jobspring Partners
# 11    San+Francisco      University of California Berkeley
# 12    San+Francisco                  Workbridge Associates
# 13    San+Francisco                         HSF Consulting
# 14    San+Francisco      University of California Berkeley
# 15    San+Francisco                  Workbridge Associates
# 16    San+Francisco                  Workbridge Associates
# 17    San+Francisco                  Workbridge Associates
# 18    San+Francisco                  Workbridge Associates
# 19    San+Francisco              Corporate Labs Technology
# 20    San+Francisco                                Brilent
# 21    San+Francisco                  Workbridge Associates
# 22    San+Francisco                                 3coast
# 23    San+Francisco      University of California Berkeley
# 24    San+Francisco                     NextGen Jane, Inc.
# 25    San+Francisco                     Jobspring Partners
# 26    San+Francisco                  Workbridge Associates
# 27    San+Francisco                  Workbridge Associates
# 28    San+Francisco                  Workbridge Associates
# 29    San+Francisco  Talent Compliance Consulting Services
# ...             ...                                    ...
# 4761        Chicago                  Workbridge Associates
# 4762        Chicago        Clinical Management Consultants
# 4763        Chicago                  Workbridge Associates
# 4764        Chicago        Clinical Management Consultants
# 4765        Chicago                  Workbridge Associates
# 4766        Chicago                  Workbridge Associates
# 4767        Chicago        Clinical Management Consultants
# 4768        Chicago                  Workbridge Associates
# 4769        Chicago                  Workbridge Associates
# 4770        Chicago        Clinical Management Consultants
# 4771        Chicago                  Workbridge Associates
# 4772        Chicago                  Workbridge Associates
# 4773        Chicago                  Workbridge Associates
# 4774        Chicago        Clinical Management Consultants
# 4775        Chicago                  Workbridge Associates
# 4776        Chicago                  Workbridge Associates
# 4777        Chicago        Clinical Management Consultants
# 4778        Chicago                  Workbridge Associates
# 4779        Chicago        Clinical Management Consultants
# 4780        Chicago                  Workbridge Associates
# 4781        Chicago        Clinical Management Consultants
# 4782        Chicago                  Workbridge Associates
# 4783        Chicago                  Workbridge Associates
# 4784        Chicago        Clinical Management Consultants
# 4785        Chicago                  Workbridge Associates
# 4786        Chicago                  Workbridge Associates
# 4787        Chicago        Clinical Management Consultants
# 4788        Chicago                  Workbridge Associates
# 4789        Chicago        Clinical Management Consultants
# 4790        Chicago                  Workbridge Associates
#
#                           salary  \
# 0                $180,000 a year
# 1     $130,000 - $180,000 a year
# 2      $80,000 - $120,000 a year
# 3     $150,000 - $180,000 a year
# 4                $140,000 a year
# 5                $300,000 a year
# 6     $100,000 - $150,000 a year
# 7                $130,000 a year
# 8                $160,000 a year
# 9     $100,000 - $150,000 a year
# 10    $150,000 - $175,000 a year
# 11       $3,811 - $3,889 a month
# 12    $100,000 - $200,000 a year
# 13               $300,000 a year
# 14      $43,692 - $51,120 a year
# 15    $130,000 - $180,000 a year
# 16    $100,000 - $200,000 a year
# 17    $130,000 - $150,000 a year
# 18    $100,000 - $140,000 a year
# 19    $110,000 - $180,000 a year
# 20               $150,000 a year
# 21    $140,000 - $200,000 a year
# 22     $80,000 - $200,000 a year
# 23      $67,500 - $81,600 a year
# 24                $65,000 a year
# 25    $180,000 - $275,000 a year
# 26    $130,000 - $150,000 a year
# 27    $100,000 - $140,000 a year
# 28    $140,000 - $200,000 a year
# 29               $100,000 a year
# ...                          ...
# 4761  $110,000 - $150,000 a year
# 4762    $71,384 - $93,274 a year
# 4763             $170,000 a year
# 4764    $71,384 - $93,274 a year
# 4765             $170,000 a year
# 4766  $110,000 - $150,000 a year
# 4767    $71,384 - $93,274 a year
# 4768             $170,000 a year
# 4769  $110,000 - $150,000 a year
# 4770    $71,384 - $93,274 a year
# 4771             $170,000 a year
# 4772  $110,000 - $150,000 a year
# 4773  $110,000 - $150,000 a year
# 4774    $71,384 - $93,274 a year
# 4775             $170,000 a year
# 4776  $110,000 - $150,000 a year
# 4777    $71,384 - $93,274 a year
# 4778             $170,000 a year
# 4779    $71,384 - $93,274 a year
# 4780             $170,000 a year
# 4781    $71,384 - $93,274 a year
# 4782             $170,000 a year
# 4783  $110,000 - $150,000 a year
# 4784    $71,384 - $93,274 a year
# 4785             $170,000 a year
# 4786  $110,000 - $150,000 a year
# 4787    $71,384 - $93,274 a year
# 4788             $170,000 a year
# 4789    $71,384 - $93,274 a year
# 4790             $170,000 a year
#
#                                                 summary  \
# 0     Data skills (SQL, Hive, Pig). Applying machine...
# 1     3+ years of industry experience in a data scie...
# 2     We are looking for a data scientist/developer ...
# 3     In this position you will share programming an...
# 4     This person will recruit, build and lead a tea...
# 5     Teams included Data Services(including data en...
# 6     Fraud Data Scientist. Seeking someone with ski...
# 7     Perform large-scale data analysis, find intere...
# 8     More data- they simply have more data than the...
# 9     Fraud Data Scientist. Seeking someone with ski...
# 10    Given the high volume of data collected by the...
# 11    Must be able to work in a greenhouse, manage d...
# 12    You will collaborate with Product, Data Engine...
# 13    Teams included Data Services(including data en...
# 14    Demonstrated experience with programming for b...
# 15    This leading company has a job opening for Pri...
# 16    You will collaborate with Product, Data Engine...
# 17    2+ years of experience in Data Scientist, Quan...
# 18    Solid experience in data science. Established ...
# 19    Machine Learning Developer Brisbane, CA Sign o...
# 20    The Brilent team brings together deep experien...
# 21    The Senior Data Scientist position requires a ...
# 22    VP - Predictive Modeling / Data Scientist. Han...
# 23    Ensures accuracy and completeness of data in m...
# 24    Scientific Researcher – Next Gen Sequencing Sc...
# 25    This is an opportunity to lead a team of talen...
# 26    2+ years of experience in Data Scientist, Quan...
# 27    Solid experience in data science. Established ...
# 28    The Senior Data Scientist position requires a ...
# 29    Strong data analysis skills including setting ...
# ...                                                 ...
# 4761  This agile team will create and develop new so...
# 4762  Manager Health Information Management Data Ana...
# 4763  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4764  Manager Health Information Management Data Ana...
# 4765  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4766  This agile team will create and develop new so...
# 4767  Manager Health Information Management Data Ana...
# 4768  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4769  This agile team will create and develop new so...
# 4770  Manager Health Information Management Data Ana...
# 4771  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4772  This agile team will create and develop new so...
# 4773  This agile team will create and develop new so...
# 4774  Manager Health Information Management Data Ana...
# 4775  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4776  This agile team will create and develop new so...
# 4777  Manager Health Information Management Data Ana...
# 4778  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4779  Manager Health Information Management Data Ana...
# 4780  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4781  Manager Health Information Management Data Ana...
# 4782  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4783  This agile team will create and develop new so...
# 4784  Manager Health Information Management Data Ana...
# 4785  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4786  This agile team will create and develop new so...
# 4787  Manager Health Information Management Data Ana...
# 4788  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4789  Manager Health Information Management Data Ana...
# 4790  Big Data with Hadoop, Hive, Impala. Mid, Senio...
#
#                                                   title  parsed_salary  \
# 0                                        Data Scientist       180000.0
# 1                                 Senior Data Scientist       155000.0
# 2                             Full-Stack Data Scientist       100000.0
# 3                                        Data Scientist       165000.0
# 4                                        Data Scientist       140000.0
# 5                                   VP of Data Services       300000.0
# 6                                  Fraud Data Scientist       125000.0
# 7                                 Senior Data Scientist       130000.0
# 8                                 Senior Data Scientist       160000.0
# 9                                  Fraud Data Scientist       125000.0
# 10                  Python Developer (Machine Learning)       162500.0
# 11                        Staff Research Associate, PMB         3850.0
# 12    Chief Algorithm Developer (Signal Processing) ...       150000.0
# 13                                  VP of Data Services       300000.0
# 14    Post-Doctoral Scholar-Employee: Analysis of om...        47406.0
# 15                             Principal Data Scientist       155000.0
# 16    Chief Algorithm Developer (Signal Processing) ...       150000.0
# 17                        Data Scientist (Econometrics)       140000.0
# 18                Data Scientist (Statistics/Economics)       120000.0
# 19                    Data Scientist (Machine Learning)       145000.0
# 20                        Senior NLP Scientist/Engineer       150000.0
# 21    Senior Data Scientist (Autonomous Vehicle Rese...       170000.0
# 22            VP - Predictive Modeling / Data Scientist       140000.0
# 23                          Database Administrator, GSE        74550.0
# 24                                Scientific Researcher        65000.0
# 25    Vice President Engineering (Big Data/ Machine ...       227500.0
# 26                        Data Scientist (Econometrics)       140000.0
# 27                Data Scientist (Statistics/Economics)       120000.0
# 28    Senior Data Scientist (Autonomous Vehicle Rese...       170000.0
# 29                            Quality Control Scientist       100000.0
# ...                                                 ...            ...
# 4761                     Senior Java Computer Scientist       130000.0
# 4762  Manager Health Information Management Data Ana...        82329.0
# 4763                         Director of Data Analytics       170000.0
# 4764  Manager Health Information Management Data Ana...        82329.0
# 4765                         Director of Data Analytics       170000.0
# 4766                     Senior Java Computer Scientist       130000.0
# 4767  Manager Health Information Management Data Ana...        82329.0
# 4768                         Director of Data Analytics       170000.0
# 4769                     Senior Java Computer Scientist       130000.0
# 4770  Manager Health Information Management Data Ana...        82329.0
# 4771                         Director of Data Analytics       170000.0
# 4772                     Senior Java Computer Scientist       130000.0
# 4773                     Senior Java Computer Scientist       130000.0
# 4774  Manager Health Information Management Data Ana...        82329.0
# 4775                         Director of Data Analytics       170000.0
# 4776                     Senior Java Computer Scientist       130000.0
# 4777  Manager Health Information Management Data Ana...        82329.0
# 4778                         Director of Data Analytics       170000.0
# 4779  Manager Health Information Management Data Ana...        82329.0
# 4780                         Director of Data Analytics       170000.0
# 4781  Manager Health Information Management Data Ana...        82329.0
# 4782                         Director of Data Analytics       170000.0
# 4783                     Senior Java Computer Scientist       130000.0
# 4784  Manager Health Information Management Data Ana...        82329.0
# 4785                         Director of Data Analytics       170000.0
# 4786                     Senior Java Computer Scientist       130000.0
# 4787  Manager Health Information Management Data Ana...        82329.0
# 4788                         Director of Data Analytics       170000.0
# 4789  Manager Health Information Management Data Ana...        82329.0
# 4790                         Director of Data Analytics       170000.0
#
#                    yearly_salary           monthly_salary range_low range_high
# 0                $180,000 a year                      NaN  $180,000       year
# 1     $130,000 - $180,000 a year                      NaN  $130,000   $180,000
# 2      $80,000 - $120,000 a year                      NaN   $80,000   $120,000
# 3     $150,000 - $180,000 a year                      NaN  $150,000   $180,000
# 4                $140,000 a year                      NaN  $140,000       year
# 5                $300,000 a year                      NaN  $300,000       year
# 6     $100,000 - $150,000 a year                      NaN  $100,000   $150,000
# 7                $130,000 a year                      NaN  $130,000       year
# 8                $160,000 a year                      NaN  $160,000       year
# 9     $100,000 - $150,000 a year                      NaN  $100,000   $150,000
# 10    $150,000 - $175,000 a year                      NaN  $150,000   $175,000
# 11                           NaN  $3,811 - $3,889 a month       NaN        NaN
# 12    $100,000 - $200,000 a year                      NaN  $100,000   $200,000
# 13               $300,000 a year                      NaN  $300,000       year
# 14      $43,692 - $51,120 a year                      NaN   $43,692    $51,120
# 15    $130,000 - $180,000 a year                      NaN  $130,000   $180,000
# 16    $100,000 - $200,000 a year                      NaN  $100,000   $200,000
# 17    $130,000 - $150,000 a year                      NaN  $130,000   $150,000
# 18    $100,000 - $140,000 a year                      NaN  $100,000   $140,000
# 19    $110,000 - $180,000 a year                      NaN  $110,000   $180,000
# 20               $150,000 a year                      NaN  $150,000       year
# 21    $140,000 - $200,000 a year                      NaN  $140,000   $200,000
# 22     $80,000 - $200,000 a year                      NaN   $80,000   $200,000
# 23      $67,500 - $81,600 a year                      NaN   $67,500    $81,600
# 24                $65,000 a year                      NaN   $65,000       year
# 25    $180,000 - $275,000 a year                      NaN  $180,000   $275,000
# 26    $130,000 - $150,000 a year                      NaN  $130,000   $150,000
# 27    $100,000 - $140,000 a year                      NaN  $100,000   $140,000
# 28    $140,000 - $200,000 a year                      NaN  $140,000   $200,000
# 29               $100,000 a year                      NaN  $100,000       year
# ...                          ...                      ...       ...        ...
# 4761  $110,000 - $150,000 a year                      NaN  $110,000   $150,000
# 4762    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4763             $170,000 a year                      NaN  $170,000       year
# 4764    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4765             $170,000 a year                      NaN  $170,000       year
# 4766  $110,000 - $150,000 a year                      NaN  $110,000   $150,000
# 4767    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4768             $170,000 a year                      NaN  $170,000       year
# 4769  $110,000 - $150,000 a year                      NaN  $110,000   $150,000
# 4770    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4771             $170,000 a year                      NaN  $170,000       year
# 4772  $110,000 - $150,000 a year                      NaN  $110,000   $150,000
# 4773  $110,000 - $150,000 a year                      NaN  $110,000   $150,000
# 4774    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4775             $170,000 a year                      NaN  $170,000       year
# 4776  $110,000 - $150,000 a year                      NaN  $110,000   $150,000
# 4777    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4778             $170,000 a year                      NaN  $170,000       year
# 4779    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4780             $170,000 a year                      NaN  $170,000       year
# 4781    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4782             $170,000 a year                      NaN  $170,000       year
# 4783  $110,000 - $150,000 a year                      NaN  $110,000   $150,000
# 4784    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4785             $170,000 a year                      NaN  $170,000       year
# 4786  $110,000 - $150,000 a year                      NaN  $110,000   $150,000
# 4787    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4788             $170,000 a year                      NaN  $170,000       year
# 4789    $71,384 - $93,274 a year                      NaN   $71,384    $93,274
# 4790             $170,000 a year                      NaN  $170,000       year
#
# [4791 rows x 10 columns]

# %%
df['range_low'] = [x.split()[0] for x in df['yearly_salary']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-c68255aa9429> in <module>()
# ----> 1 df['range_low'] = [x.split()[0] for x in df['yearly_salary']]
#
# AttributeError: 'float' object has no attribute 'split'

# %%
for x in df.yearly_salary: 
    try:
        print x
        print x.split()
        print x.split()[0]
        print x.split()[2]
        print ''
    except:
        pass
# Out:
# $180,000 a year
# ['$180,000', 'a', 'year']
# $180,000
# year
#
# $130,000 - $180,000 a year
# ['$130,000', '-', '$180,000', 'a', 'year']
# $130,000
# $180,000
#
# $80,000 - $120,000 a year
# ['$80,000', '-', '$120,000', 'a', 'year']
# $80,000
# $120,000
#
# $150,000 - $180,000 a year
# ['$150,000', '-', '$180,000', 'a', 'year']
# $150,000
# $180,000
#
# $140,000 a year
# ['$140,000', 'a', 'year']
# $140,000
# year
#
# $300,000 a year
# ['$300,000', 'a', 'year']
# $300,000
# year
#
# $100,000 - $150,000 a year
# ['$100,000', '-', '$150,000', 'a', 'year']
# $100,000
# $150,000
#
# $130,000 a year
# ['$130,000', 'a', 'year']
# $130,000
# year
#
# $160,000 a year
# ['$160,000', 'a', 'year']
# $160,000
# year
#
# $100,000 - $150,000 a year
# ['$100,000', '-', '$150,000', 'a', 'year']
# $100,000
# $150,000
#
# $150,000 - $175,000 a year
# ['$150,000', '-', '$175,000', 'a', 'year']
# $150,000
# $175,000
#
# nan
# $100,000 - $200,000 a year
# ['$100,000', '-', '$200,000', 'a', 'year']
# $100,000
# $200,000
#
# $300,000 a year
# ['$300,000', 'a', 'year']
# $300,000
# year
#
# $43,692 - $51,120 a year
# ['$43,692', '-', '$51,120', 'a', 'year']
# $43,692
# $51,120
#
# $130,000 - $180,000 a year
# ['$130,000', '-', '$180,000', 'a', 'year']
# $130,000
# $180,000
#
# $100,000 - $200,000 a year
# ['$100,000', '-', '$200,000', 'a', 'year']
# $100,000
# $200,000
#
# $130,000 - $150,000 a year
# ['$130,000', '-', '$150,000', 'a', 'year']
# $130,000
# $150,000
#
# $100,000 - $140,000 a year
# ['$100,000', '-', '$140,000', 'a', 'year']
# $100,000
# $140,000
#
# $110,000 - $180,000 a year
# ['$110,000', '-', '$180,000', 'a', 'year']
# $110,000
# $180,000
#
# $150,000 a year
# ['$150,000', 'a', 'year']
# $150,000
# year
#
# $140,000 - $200,000 a year
# ['$140,000', '-', '$200,000', 'a', 'year']
# $140,000
# $200,000
#
# $80,000 - $200,000 a year
# ['$80,000', '-', '$200,000', 'a', 'year']
# $80,000
# $200,000
#
# $67,500 - $81,600 a year
# ['$67,500', '-', '$81,600', 'a', 'year']
# $67,500
# $81,600
#
# $65,000 a year
# ['$65,000', 'a', 'year']
# $65,000
# year
#
# $180,000 - $275,000 a year
# ['$180,000', '-', '$275,000', 'a', 'year']
# $180,000
# $275,000
#
# $130,000 - $150,000 a year
# ['$130,000', '-', '$150,000', 'a', 'year']
# $130,000
# $150,000
#
# $100,000 - $140,000 a year
# ['$100,000', '-', '$140,000', 'a', 'year']
# $100,000
# $140,000
#
# $140,000 - $200,000 a year
# ['$140,000', '-', '$200,000', 'a', 'year']
# $140,000
# $200,000
#
# $100,000 a year
# ['$100,000', 'a', 'year']
# $100,000
# year
#
# nan
# $50,400 - $60,000 a year
# ['$50,400', '-', '$60,000', 'a', 'year']
# $50,400
# $60,000
#
# $110,000 - $130,000 a year
# ['$110,000', '-', '$130,000', 'a', 'year']
# $110,000
# $130,000
#
# $110,000 - $180,000 a year
# ['$110,000', '-', '$180,000', 'a', 'year']
# $110,000
# $180,000
#
# $130,000 - $175,000 a year
# ['$130,000', '-', '$175,000', 'a', 'year']
# $130,000
# $175,000
#
# $165,000 - $195,000 a year
# ['$165,000', '-', '$195,000', 'a', 'year']
# $165,000
# $195,000
#
# $120,000 - $150,000 a year
# ['$120,000', '-', '$150,000', 'a', 'year']
# $120,000
# $150,000
#
# $120,000 - $140,000 a year
# ['$120,000', '-', '$140,000', 'a', 'year']
# $120,000
# $140,000
#
# $160,000 a year
# ['$160,000', 'a', 'year']
# $160,000
# year
#
# $150,000 - $200,000 a year
# ['$150,000', '-', '$200,000', 'a', 'year']
# $150,000
# $200,000
#
# $150,000 a year
# ['$150,000', 'a', 'year']
# $150,000
# year
#
# $110,000 - $130,000 a year
# ['$110,000', '-', '$130,000', 'a', 'year']
# $110,000
# $130,000
#
# $180,000 - $275,000 a year
# ['$180,000', '-', '$275,000', 'a', 'year']
# $180,000
# $275,000
#
# $130,000 - $175,000 a year
# ['$130,000', '-', '$175,000', 'a', 'year']
# $130,000
# $175,000
#
# $125,000 a year
# ['$125,000', 'a', 'year']
# $125,000
# year
#
# $200,000 a year
# ['$200,000', 'a', 'year']
# $200,000
# year
#
# nan
# $180,000 a year
# ['$180,000', 'a', 'year']
# $180,000
# year
#
# $49,012 a year
# ['$49,012', 'a', 'year']
# $49,012
# year
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $120,000 - $155,000 a year
# ['$120,000', '-', '$155,000', 'a', 'year']
# $120,000
# $155,000
#
# $117,500 - $127,500 a year
# ['$117,500', '-', '$127,500', 'a', 'year']
# $117,500
# $127,500
#
# $140,000 a year
# ['$140,000', 'a', 'year']
# $140,000
# year
#
# $117,500 - $127,500 a year
# ['$117,500', '-', '$127,500', 'a', 'year']
# $117,500
# $127,500
#
# $140,000 a year
# ['$140,000', 'a', 'year']
# $140,000
# year
#
# $140,000 a year
# ['$140,000', 'a', 'year']
# $140,000
# year
#
# $100,000 a year
# ['$100,000', 'a', 'year']
# $100,000
# year
#
# $85,211 - $110,522 a year
# ['$85,211', '-', '$110,522', 'a', 'year']
# $85,211
# $110,522
#
# $100,000 - $200,000 a year
# ['$100,000', '-', '$200,000', 'a', 'year']
# $100,000
# $200,000
#
# $200,000 a year
# ['$200,000', 'a', 'year']
# $200,000
# year
#
# $200,000 a year
# ['$200,000', 'a', 'year']
# $200,000
# year
#
# $57,969 - $62,000 a year
# ['$57,969', '-', '$62,000', 'a', 'year']
# $57,969
# $62,000
#
# $105,000 a year
# ['$105,000', 'a', 'year']
# $105,000
# year
#
# $115,000 a year
# ['$115,000', 'a', 'year']
# $115,000
# year
#
# $60,000 - $90,000 a year
# ['$60,000', '-', '$90,000', 'a', 'year']
# $60,000
# $90,000
#
# $100,000 - $200,000 a year
# ['$100,000', '-', '$200,000', 'a', 'year']
# $100,000
# $200,000
#
# $105,000 a year
# ['$105,000', 'a', 'year']
# $105,000
# year
#
# $115,000 a year
# ['$115,000', 'a', 'year']
# $115,000
# year
#
# $60,000 - $90,000 a year
# ['$60,000', '-', '$90,000', 'a', 'year']
# $60,000
# $90,000
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $80,000 a year
# ['$80,000', 'a', 'year']
# $80,000
# year
#
# $180,000 - $250,000 a year
# ['$180,000', '-', '$250,000', 'a', 'year']
# $180,000
# $250,000
#
# $100,000 - $200,000 a year
# ['$100,000', '-', '$200,000', 'a', 'year']
# $100,000
# $200,000
#
# $200,000 - $300,000 a year
# ['$200,000', '-', '$300,000', 'a', 'year']
# $200,000
# $300,000
#
# $80,000 - $120,000 a year
# ['$80,000', '-', '$120,000', 'a', 'year']
# $80,000
# $120,000
#
# $140,000 - $150,000 a year
# ['$140,000', '-', '$150,000', 'a', 'year']
# $140,000
# $150,000
#
# $100,000 a year
# ['$100,000', 'a', 'year']
# $100,000
# year
#
# $130,000 a year
# ['$130,000', 'a', 'year']
# $130,000
# year
#
# $180,000 - $250,000 a year
# ['$180,000', '-', '$250,000', 'a', 'year']
# $180,000
# $250,000
#
# $140,000 - $150,000 a year
# ['$140,000', '-', '$150,000', 'a', 'year']
# $140,000
# $150,000
#
# $130,000 - $175,000 a year
# ['$130,000', '-', '$175,000', 'a', 'year']
# $130,000
# $175,000
#
# $140,000 - $200,000 a year
# ['$140,000', '-', '$200,000', 'a', 'year']
# $140,000
# $200,000
#
# $150,000 - $250,000 a year
# ['$150,000', '-', '$250,000', 'a', 'year']
# $150,000
# $250,000
#
# $80,000 - $120,000 a year
# ['$80,000', '-', '$120,000', 'a', 'year']
# $80,000
# $120,000
#
# nan
# $53,875 a year
# ['$53,875', 'a', 'year']
# $53,875
# year
#
# $150,000 - $200,000 a year
# ['$150,000', '-', '$200,000', 'a', 'year']
# $150,000
# $200,000
#
# $130,000 - $160,000 a year
# ['$130,000', '-', '$160,000', 'a', 'year']
# $130,000
# $160,000
#
# $175,000 - $275,000 a year
# ['$175,000', '-', '$275,000', 'a', 'year']
# $175,000
# $275,000
#
# $76,340 - $100,322 a year
# ['$76,340', '-', '$100,322', 'a', 'year']
# $76,340
# $100,322
#
# $61,000 - $62,000 a year
# ['$61,000', '-', '$62,000', 'a', 'year']
# $61,000
# $62,000
#
# $150,000 a year
# ['$150,000', 'a', 'year']
# $150,000
# year
#
# $100,000 a year
# ['$100,000', 'a', 'year']
# $100,000
# year
#
# $200,000 a year
# ['$200,000', 'a', 'year']
# $200,000
# year
#
# $150,000 a year
# ['$150,000', 'a', 'year']
# $150,000
# year
#
# $80,000 - $200,000 a year
# ['$80,000', '-', '$200,000', 'a', 'year']
# $80,000
# $200,000
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $61,000 - $62,000 a year
# ['$61,000', '-', '$62,000', 'a', 'year']
# $61,000
# $62,000
#
# $70,000 - $80,000 a year
# ['$70,000', '-', '$80,000', 'a', 'year']
# $70,000
# $80,000
#
# $150,000 - $200,000 a year
# ['$150,000', '-', '$200,000', 'a', 'year']
# $150,000
# $200,000
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $130,000 - $160,000 a year
# ['$130,000', '-', '$160,000', 'a', 'year']
# $130,000
# $160,000
#
# nan
# $70,000 - $80,000 a year
# ['$70,000', '-', '$80,000', 'a', 'year']
# $70,000
# $80,000
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $57,969 - $70,142 a year
# ['$57,969', '-', '$70,142', 'a', 'year']
# $57,969
# $70,142
#
# $68,239 - $80,000 a year
# ['$68,239', '-', '$80,000', 'a', 'year']
# $68,239
# $80,000
#
# $85,000 a year
# ['$85,000', 'a', 'year']
# $85,000
# year
#
# $76,340 - $100,322 a year
# ['$76,340', '-', '$100,322', 'a', 'year']
# $76,340
# $100,322
#
# $65,000 a year
# ['$65,000', 'a', 'year']
# $65,000
# year
#
# $77,000 - $90,000 a year
# ['$77,000', '-', '$90,000', 'a', 'year']
# $77,000
# $90,000
#
# $100,000 - $140,000 a year
# ['$100,000', '-', '$140,000', 'a', 'year']
# $100,000
# $140,000
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $120,000 - $150,000 a year
# ['$120,000', '-', '$150,000', 'a', 'year']
# $120,000
# $150,000
#
# $68,239 - $85,556 a year
# ['$68,239', '-', '$85,556', 'a', 'year']
# $68,239
# $85,556
#
# $80,000 - $200,000 a year
# ['$80,000', '-', '$200,000', 'a', 'year']
# $80,000
# $200,000
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $57,969 - $70,142 a year
# ['$57,969', '-', '$70,142', 'a', 'year']
# $57,969
# $70,142
#
# $57,969 - $70,142 a year
# ['$57,969', '-', '$70,142', 'a', 'year']
# $57,969
# $70,142
#
# $41,057 - $61,669 a year
# ['$41,057', '-', '$61,669', 'a', 'year']
# $41,057
# $61,669
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $65,000 a year
# ['$65,000', 'a', 'year']
# $65,000
# year
#
# $77,000 - $90,000 a year
# ['$77,000', '-', '$90,000', 'a', 'year']
# $77,000
# $90,000
#
# $65,000 a year
# ['$65,000', 'a', 'year']
# $65,000
# year
#
# $57,969 - $70,142 a year
# ['$57,969', '-', '$70,142', 'a', 'year']
# $57,969
# $70,142
#
# $76,340 - $100,322 a year
# ['$76,340', '-', '$100,322', 'a', 'year']
# $76,340
# $100,322
#
# $57,969 a year
# ['$57,969', 'a', 'year']
# $57,969
# year
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $66,575 - $76,561 a year
# ['$66,575', '-', '$76,561', 'a', 'year']
# $66,575
# $76,561
#
# $69,749 a year
# ['$69,749', 'a', 'year']
# $69,749
# year
#
# $50,000 - $60,000 a year
# ['$50,000', '-', '$60,000', 'a', 'year']
# $50,000
# $60,000
#
# $68,239 - $80,000 a year
# ['$68,239', '-', '$80,000', 'a', 'year']
# $68,239
# $80,000
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $120,000 a year
# ['$120,000', 'a', 'year']
# $120,000
# year
#
# $120,000 a year
# ['$120,000', 'a', 'year']
# $120,000
# year
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $60,000 - $68,000 a year
# ['$60,000', '-', '$68,000', 'a', 'year']
# $60,000
# $68,000
#
# $40,000 - $65,000 a year
# ['$40,000', '-', '$65,000', 'a', 'year']
# $40,000
# $65,000
#
# $50,000 - $65,000 a year
# ['$50,000', '-', '$65,000', 'a', 'year']
# $50,000
# $65,000
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $200,000 a year
# ['$200,000', 'a', 'year']
# $200,000
# year
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $40,000 - $50,000 a year
# ['$40,000', '-', '$50,000', 'a', 'year']
# $40,000
# $50,000
#
# $41,993 - $53,606 a year
# ['$41,993', '-', '$53,606', 'a', 'year']
# $41,993
# $53,606
#
# $42,000 - $52,000 a year
# ['$42,000', '-', '$52,000', 'a', 'year']
# $42,000
# $52,000
#
# $185,000 a year
# ['$185,000', 'a', 'year']
# $185,000
# year
#
# $65,000 a year
# ['$65,000', 'a', 'year']
# $65,000
# year
#
# $75,000 a year
# ['$75,000', 'a', 'year']
# $75,000
# year
#
# $57,969 - $70,142 a year
# ['$57,969', '-', '$70,142', 'a', 'year']
# $57,969
# $70,142
#
# $69,749 a year
# ['$69,749', 'a', 'year']
# $69,749
# year
#
# $200,000 a year
# ['$200,000', 'a', 'year']
# $200,000
# year
#
# $76,340 - $87,791 a year
# ['$76,340', '-', '$87,791', 'a', 'year']
# $76,340
# $87,791
#
# $65,000 a year
# ['$65,000', 'a', 'year']
# $65,000
# year
#
# $140,000 - $180,000 a year
# ['$140,000', '-', '$180,000', 'a', 'year']
# $140,000
# $180,000
#
# $42,000 - $52,000 a year
# ['$42,000', '-', '$52,000', 'a', 'year']
# $42,000
# $52,000
#
# $68,239 - $85,644 a year
# ['$68,239', '-', '$85,644', 'a', 'year']
# $68,239
# $85,644
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# $140,000 - $160,000 a year
# ['$140,000', '-', '$160,000', 'a', 'year']
# $140,000
# $160,000
#
# ...
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $110,000 - $150,000 a year
# ['$110,000', '-', '$150,000', 'a', 'year']
# $110,000
# $150,000
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year
#
# $71,384 - $93,274 a year
# ['$71,384', '-', '$93,274', 'a', 'year']
# $71,384
# $93,274
#
# $170,000 a year
# ['$170,000', 'a', 'year']
# $170,000
# year

# %%
df
# Out:
#                city                                company  \
# 0     San+Francisco                            MarkMonitor
# 1     San+Francisco                  Workbridge Associates
# 2     San+Francisco                               Mines.io
# 3     San+Francisco                  Workbridge Associates
# 4     San+Francisco                Smith Hanley Associates
# 5     San+Francisco                         HSF Consulting
# 6     San+Francisco                       All-In Analytics
# 7     San+Francisco                                Brilent
# 8     San+Francisco                         HSF Consulting
# 9     San+Francisco                       All-In Analytics
# 10    San+Francisco                     Jobspring Partners
# 11    San+Francisco      University of California Berkeley
# 12    San+Francisco                  Workbridge Associates
# 13    San+Francisco                         HSF Consulting
# 14    San+Francisco      University of California Berkeley
# 15    San+Francisco                  Workbridge Associates
# 16    San+Francisco                  Workbridge Associates
# 17    San+Francisco                  Workbridge Associates
# 18    San+Francisco                  Workbridge Associates
# 19    San+Francisco              Corporate Labs Technology
# 20    San+Francisco                                Brilent
# 21    San+Francisco                  Workbridge Associates
# 22    San+Francisco                                 3coast
# 23    San+Francisco      University of California Berkeley
# 24    San+Francisco                     NextGen Jane, Inc.
# 25    San+Francisco                     Jobspring Partners
# 26    San+Francisco                  Workbridge Associates
# 27    San+Francisco                  Workbridge Associates
# 28    San+Francisco                  Workbridge Associates
# 29    San+Francisco  Talent Compliance Consulting Services
# ...             ...                                    ...
# 4761        Chicago                  Workbridge Associates
# 4762        Chicago        Clinical Management Consultants
# 4763        Chicago                  Workbridge Associates
# 4764        Chicago        Clinical Management Consultants
# 4765        Chicago                  Workbridge Associates
# 4766        Chicago                  Workbridge Associates
# 4767        Chicago        Clinical Management Consultants
# 4768        Chicago                  Workbridge Associates
# 4769        Chicago                  Workbridge Associates
# 4770        Chicago        Clinical Management Consultants
# 4771        Chicago                  Workbridge Associates
# 4772        Chicago                  Workbridge Associates
# 4773        Chicago                  Workbridge Associates
# 4774        Chicago        Clinical Management Consultants
# 4775        Chicago                  Workbridge Associates
# 4776        Chicago                  Workbridge Associates
# 4777        Chicago        Clinical Management Consultants
# 4778        Chicago                  Workbridge Associates
# 4779        Chicago        Clinical Management Consultants
# 4780        Chicago                  Workbridge Associates
# 4781        Chicago        Clinical Management Consultants
# 4782        Chicago                  Workbridge Associates
# 4783        Chicago                  Workbridge Associates
# 4784        Chicago        Clinical Management Consultants
# 4785        Chicago                  Workbridge Associates
# 4786        Chicago                  Workbridge Associates
# 4787        Chicago        Clinical Management Consultants
# 4788        Chicago                  Workbridge Associates
# 4789        Chicago        Clinical Management Consultants
# 4790        Chicago                  Workbridge Associates
#
#                           salary  \
# 0                $180,000 a year
# 1     $130,000 - $180,000 a year
# 2      $80,000 - $120,000 a year
# 3     $150,000 - $180,000 a year
# 4                $140,000 a year
# 5                $300,000 a year
# 6     $100,000 - $150,000 a year
# 7                $130,000 a year
# 8                $160,000 a year
# 9     $100,000 - $150,000 a year
# 10    $150,000 - $175,000 a year
# 11       $3,811 - $3,889 a month
# 12    $100,000 - $200,000 a year
# 13               $300,000 a year
# 14      $43,692 - $51,120 a year
# 15    $130,000 - $180,000 a year
# 16    $100,000 - $200,000 a year
# 17    $130,000 - $150,000 a year
# 18    $100,000 - $140,000 a year
# 19    $110,000 - $180,000 a year
# 20               $150,000 a year
# 21    $140,000 - $200,000 a year
# 22     $80,000 - $200,000 a year
# 23      $67,500 - $81,600 a year
# 24                $65,000 a year
# 25    $180,000 - $275,000 a year
# 26    $130,000 - $150,000 a year
# 27    $100,000 - $140,000 a year
# 28    $140,000 - $200,000 a year
# 29               $100,000 a year
# ...                          ...
# 4761  $110,000 - $150,000 a year
# 4762    $71,384 - $93,274 a year
# 4763             $170,000 a year
# 4764    $71,384 - $93,274 a year
# 4765             $170,000 a year
# 4766  $110,000 - $150,000 a year
# 4767    $71,384 - $93,274 a year
# 4768             $170,000 a year
# 4769  $110,000 - $150,000 a year
# 4770    $71,384 - $93,274 a year
# 4771             $170,000 a year
# 4772  $110,000 - $150,000 a year
# 4773  $110,000 - $150,000 a year
# 4774    $71,384 - $93,274 a year
# 4775             $170,000 a year
# 4776  $110,000 - $150,000 a year
# 4777    $71,384 - $93,274 a year
# 4778             $170,000 a year
# 4779    $71,384 - $93,274 a year
# 4780             $170,000 a year
# 4781    $71,384 - $93,274 a year
# 4782             $170,000 a year
# 4783  $110,000 - $150,000 a year
# 4784    $71,384 - $93,274 a year
# 4785             $170,000 a year
# 4786  $110,000 - $150,000 a year
# 4787    $71,384 - $93,274 a year
# 4788             $170,000 a year
# 4789    $71,384 - $93,274 a year
# 4790             $170,000 a year
#
#                                                 summary  \
# 0     Data skills (SQL, Hive, Pig). Applying machine...
# 1     3+ years of industry experience in a data scie...
# 2     We are looking for a data scientist/developer ...
# 3     In this position you will share programming an...
# 4     This person will recruit, build and lead a tea...
# 5     Teams included Data Services(including data en...
# 6     Fraud Data Scientist. Seeking someone with ski...
# 7     Perform large-scale data analysis, find intere...
# 8     More data- they simply have more data than the...
# 9     Fraud Data Scientist. Seeking someone with ski...
# 10    Given the high volume of data collected by the...
# 11    Must be able to work in a greenhouse, manage d...
# 12    You will collaborate with Product, Data Engine...
# 13    Teams included Data Services(including data en...
# 14    Demonstrated experience with programming for b...
# 15    This leading company has a job opening for Pri...
# 16    You will collaborate with Product, Data Engine...
# 17    2+ years of experience in Data Scientist, Quan...
# 18    Solid experience in data science. Established ...
# 19    Machine Learning Developer Brisbane, CA Sign o...
# 20    The Brilent team brings together deep experien...
# 21    The Senior Data Scientist position requires a ...
# 22    VP - Predictive Modeling / Data Scientist. Han...
# 23    Ensures accuracy and completeness of data in m...
# 24    Scientific Researcher – Next Gen Sequencing Sc...
# 25    This is an opportunity to lead a team of talen...
# 26    2+ years of experience in Data Scientist, Quan...
# 27    Solid experience in data science. Established ...
# 28    The Senior Data Scientist position requires a ...
# 29    Strong data analysis skills including setting ...
# ...                                                 ...
# 4761  This agile team will create and develop new so...
# 4762  Manager Health Information Management Data Ana...
# 4763  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4764  Manager Health Information Management Data Ana...
# 4765  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4766  This agile team will create and develop new so...
# 4767  Manager Health Information Management Data Ana...
# 4768  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4769  This agile team will create and develop new so...
# 4770  Manager Health Information Management Data Ana...
# 4771  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4772  This agile team will create and develop new so...
# 4773  This agile team will create and develop new so...
# 4774  Manager Health Information Management Data Ana...
# 4775  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4776  This agile team will create and develop new so...
# 4777  Manager Health Information Management Data Ana...
# 4778  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4779  Manager Health Information Management Data Ana...
# 4780  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4781  Manager Health Information Management Data Ana...
# 4782  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4783  This agile team will create and develop new so...
# 4784  Manager Health Information Management Data Ana...
# 4785  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4786  This agile team will create and develop new so...
# 4787  Manager Health Information Management Data Ana...
# 4788  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4789  Manager Health Information Management Data Ana...
# 4790  Big Data with Hadoop, Hive, Impala. Mid, Senio...
#
#                                                   title  parsed_salary  \
# 0                                        Data Scientist       180000.0
# 1                                 Senior Data Scientist       155000.0
# 2                             Full-Stack Data Scientist       100000.0
# 3                                        Data Scientist       165000.0
# 4                                        Data Scientist       140000.0
# 5                                   VP of Data Services       300000.0
# 6                                  Fraud Data Scientist       125000.0
# 7                                 Senior Data Scientist       130000.0
# 8                                 Senior Data Scientist       160000.0
# 9                                  Fraud Data Scientist       125000.0
# 10                  Python Developer (Machine Learning)       162500.0
# 11                        Staff Research Associate, PMB         3850.0
# 12    Chief Algorithm Developer (Signal Processing) ...       150000.0
# 13                                  VP of Data Services       300000.0
# 14    Post-Doctoral Scholar-Employee: Analysis of om...        47406.0
# 15                             Principal Data Scientist       155000.0
# 16    Chief Algorithm Developer (Signal Processing) ...       150000.0
# 17                        Data Scientist (Econometrics)       140000.0
# 18                Data Scientist (Statistics/Economics)       120000.0
# 19                    Data Scientist (Machine Learning)       145000.0
# 20                        Senior NLP Scientist/Engineer       150000.0
# 21    Senior Data Scientist (Autonomous Vehicle Rese...       170000.0
# 22            VP - Predictive Modeling / Data Scientist       140000.0
# 23                          Database Administrator, GSE        74550.0
# 24                                Scientific Researcher        65000.0
# 25    Vice President Engineering (Big Data/ Machine ...       227500.0
# 26                        Data Scientist (Econometrics)       140000.0
# 27                Data Scientist (Statistics/Economics)       120000.0
# 28    Senior Data Scientist (Autonomous Vehicle Rese...       170000.0
# 29                            Quality Control Scientist       100000.0
# ...                                                 ...            ...
# 4761                     Senior Java Computer Scientist       130000.0
# 4762  Manager Health Information Management Data Ana...        82329.0
# 4763                         Director of Data Analytics       170000.0
# 4764  Manager Health Information Management Data Ana...        82329.0
# 4765                         Director of Data Analytics       170000.0
# 4766                     Senior Java Computer Scientist       130000.0
# 4767  Manager Health Information Management Data Ana...        82329.0
# 4768                         Director of Data Analytics       170000.0
# 4769                     Senior Java Computer Scientist       130000.0
# 4770  Manager Health Information Management Data Ana...        82329.0
# 4771                         Director of Data Analytics       170000.0
# 4772                     Senior Java Computer Scientist       130000.0
# 4773                     Senior Java Computer Scientist       130000.0
# 4774  Manager Health Information Management Data Ana...        82329.0
# 4775                         Director of Data Analytics       170000.0
# 4776                     Senior Java Computer Scientist       130000.0
# 4777  Manager Health Information Management Data Ana...        82329.0
# 4778                         Director of Data Analytics       170000.0
# 4779  Manager Health Information Management Data Ana...        82329.0
# 4780                         Director of Data Analytics       170000.0
# 4781  Manager Health Information Management Data Ana...        82329.0
# 4782                         Director of Data Analytics       170000.0
# 4783                     Senior Java Computer Scientist       130000.0
# 4784  Manager Health Information Management Data Ana...        82329.0
# 4785                         Director of Data Analytics       170000.0
# 4786                     Senior Java Computer Scientist       130000.0
# 4787  Manager Health Information Management Data Ana...        82329.0
# 4788                         Director of Data Analytics       170000.0
# 4789  Manager Health Information Management Data Ana...        82329.0
# 4790                         Director of Data Analytics       170000.0
#
#                    yearly_salary           monthly_salary range_low range_high
# 0                $180,000 a year                      NaN  $170,000       year
# 1     $130,000 - $180,000 a year                      NaN  $170,000       year
# 2      $80,000 - $120,000 a year                      NaN  $170,000       year
# 3     $150,000 - $180,000 a year                      NaN  $170,000       year
# 4                $140,000 a year                      NaN  $170,000       year
# 5                $300,000 a year                      NaN  $170,000       year
# 6     $100,000 - $150,000 a year                      NaN  $170,000       year
# 7                $130,000 a year                      NaN  $170,000       year
# 8                $160,000 a year                      NaN  $170,000       year
# 9     $100,000 - $150,000 a year                      NaN  $170,000       year
# 10    $150,000 - $175,000 a year                      NaN  $170,000       year
# 11                           NaN  $3,811 - $3,889 a month  $170,000       year
# 12    $100,000 - $200,000 a year                      NaN  $170,000       year
# 13               $300,000 a year                      NaN  $170,000       year
# 14      $43,692 - $51,120 a year                      NaN  $170,000       year
# 15    $130,000 - $180,000 a year                      NaN  $170,000       year
# 16    $100,000 - $200,000 a year                      NaN  $170,000       year
# 17    $130,000 - $150,000 a year                      NaN  $170,000       year
# 18    $100,000 - $140,000 a year                      NaN  $170,000       year
# 19    $110,000 - $180,000 a year                      NaN  $170,000       year
# 20               $150,000 a year                      NaN  $170,000       year
# 21    $140,000 - $200,000 a year                      NaN  $170,000       year
# 22     $80,000 - $200,000 a year                      NaN  $170,000       year
# 23      $67,500 - $81,600 a year                      NaN  $170,000       year
# 24                $65,000 a year                      NaN  $170,000       year
# 25    $180,000 - $275,000 a year                      NaN  $170,000       year
# 26    $130,000 - $150,000 a year                      NaN  $170,000       year
# 27    $100,000 - $140,000 a year                      NaN  $170,000       year
# 28    $140,000 - $200,000 a year                      NaN  $170,000       year
# 29               $100,000 a year                      NaN  $170,000       year
# ...                          ...                      ...       ...        ...
# 4761  $110,000 - $150,000 a year                      NaN  $170,000       year
# 4762    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4763             $170,000 a year                      NaN  $170,000       year
# 4764    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4765             $170,000 a year                      NaN  $170,000       year
# 4766  $110,000 - $150,000 a year                      NaN  $170,000       year
# 4767    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4768             $170,000 a year                      NaN  $170,000       year
# 4769  $110,000 - $150,000 a year                      NaN  $170,000       year
# 4770    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4771             $170,000 a year                      NaN  $170,000       year
# 4772  $110,000 - $150,000 a year                      NaN  $170,000       year
# 4773  $110,000 - $150,000 a year                      NaN  $170,000       year
# 4774    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4775             $170,000 a year                      NaN  $170,000       year
# 4776  $110,000 - $150,000 a year                      NaN  $170,000       year
# 4777    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4778             $170,000 a year                      NaN  $170,000       year
# 4779    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4780             $170,000 a year                      NaN  $170,000       year
# 4781    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4782             $170,000 a year                      NaN  $170,000       year
# 4783  $110,000 - $150,000 a year                      NaN  $170,000       year
# 4784    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4785             $170,000 a year                      NaN  $170,000       year
# 4786  $110,000 - $150,000 a year                      NaN  $170,000       year
# 4787    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4788             $170,000 a year                      NaN  $170,000       year
# 4789    $71,384 - $93,274 a year                      NaN  $170,000       year
# 4790             $170,000 a year                      NaN  $170,000       year
#
# [4791 rows x 10 columns]

# %% [markdown]
# ## Predicting salaries using Logistic Regression

# %% [markdown]
# #### Load in the the data of scraped salaries

# %%
## YOUR CODE HERE

# %% [markdown]
# #### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Thought experiment: What is the baseline accuracy for this model?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a Logistic Regression model to predict High/Low salary using statsmodel. Start by ONLY using the location as a feature. Display the coefficients and write a short summary of what they mean.

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a few new variables in your dataframe to represent interesting features of a job title.
# - For example, create a feature that represents whether 'Senior' is in the title
# - or whether 'Manager' is in the title.
# - Then build a new Logistic Regression model with these features. Do they add any value?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Rebuild this model with scikit-learn.
# - You can either create the dummy features manually or use the `dmatrix` function from `patsy`
# - Remember to scale the feature variables as well!

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Use cross-validation in scikit-learn to evaluate the model above.
# - Evaluate the accuracy, AUC, precision and recall of the model.
# - Discuss the differences and explain when you want a high-recall or a high-precision model in this scenario.

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Compare L1 and L2 regularization for this logistic regression model. What effect does this have on the coefficients learned?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Continue to incorporate other text features from the title or summary that you believe will predict the salary and examine their coefficients

# %% [markdown]
# #### Take ~100 scraped entries with salaries. Convert them to use with your model and predict the salary - which entries have the highest predicted salaries?

# %% [markdown]
# ### BONUS

# %% [markdown]
# #### Bonus: Use Count Vectorizer from scikit-learn to create features from the text summaries.
# - Examine using count or binary features in the model
# - Re-evaluate the logistic regression model using these. Does this improve the model performance?
# - What text features are the most valuable?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Re-test L1 and L2 regularization. You can use LogisticRegressionCV to find the optimal reguarlization parameters.
# - Re-test what text features are most valuable.
# - How do L1 and L2 change the coefficients?

# %%
## YOUR CODE HERE
